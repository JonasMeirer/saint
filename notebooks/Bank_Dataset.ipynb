# %% [markdown]
# # Bank dataset example

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ogunlao/saint/blob/main/notebooks/Bank_Dataset.ipynb)

# %% [markdown]
# This notebook example is made to run seamlessly on colab. You may need to change the paths to run on local.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# clone the repository

# !git clone https://github.com/ogunlao/saint.git

# %%
# !pip install -r saint/requirements.txt

# %% [markdown]
# **warning: restart the runtime on Colab**

# %% [markdown]
# ## General setup configuration parameters from paper

# %%
import os

import torch
import pandas as pd
import numpy as np

# %%
# --- Config Information ---#
try:
    from ruamel.yaml import YAML
except ModuleNotFoundError:
    from ruamel_yaml import YAML

config_path = 'configs/config.yaml'

yaml = YAML(typ='safe')
with open(config_path) as f:
    args = yaml.load(f)

print(args)
# Out:
# {'defaults': ['_self_', {'experiment': 'self-supervised'}, {'data': 'bank_ssl'}], 'seed': 1234, 'transformer': {'num_layers': 6, 'num_heads': 8, 'dropout': 0.1, 'dropout_ff': 0.1, 'embed_dim': 32, 'd_ff': 32, 'cls_token_idx': 0}, 'augmentation': {'prob_cutmix': 0.3, 'alpha': 0.2, 'lambda_pt': 10}, 'optimizer': {'temperature': 0.7, 'proj_head_dim': 128, 'beta_1': 0.9, 'beta_2': 0.99, 'lr': 0.0001, 'weight_decay': 0.01, 'optim': 'adamw', 'metric': 'auroc'}, 'preproc': {'data_folder': None, 'train_split': 0.65, 'validation_split': 0.15, 'test_split': 0.2, 'num_supervised_train_data': None}, 'callback': {'monitor': 'val_loss', 'mode': 'min', 'auto_insert_metric_name': False}, 'trainer': {'max_epochs': 100, 'deterministic': True, 'default_root_dir': None}, 'dataloader': {'shuffle_val': False, 'train_bs': 32, 'val_bs': 32, 'test_bs': 16, 'num_workers': 2, 'pin_memory': False}, 'metric': '${optimizer.metric}', 'print_config': False}

# %% [markdown]
# ## Dataset preprocessing

# %% [markdown]
# ###### Bank dataset [Link](https://archive.ics.uci.edu/ml/datasets/bank+marketing)

# %%
data_folder = "data/bank"

if False:
    # download the data into a data folder
    URL_LINK = "https://archive.ics.uci.edu/ml/machine-learning-databases/00222/bank.zip"

    # !wget -P {data_folder} {URL_LINK}
    # !unzip {data_folder}/bank.zip -d {data_folder}

# %%
bank_df = pd.read_csv(os.path.join(data_folder, 'bank-full.csv'),  sep=';')
y = bank_df[['y']].copy()

bank_df.drop(columns=['y'], inplace=True)
bank_df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome
# 0  unknown    5   may       261         1     -1         0  unknown
# 1  unknown    5   may       151         1     -1         0  unknown
# 2  unknown    5   may        76         1     -1         0  unknown
# 3  unknown    5   may        92         1     -1         0  unknown
# 4  unknown    5   may       198         1     -1         0  unknown

# %%
len(y) # Data size should be 45211
# Out:
# 45211

# %%
y.value_counts() # Data is imbalanced, will require some balanced sampling
# Out:
# y
# no     39922
# yes     5289
# Name: count, dtype: int64

# %%
# check if there are any missing values
bank_df.isna().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# dtype: int64

# %%
from src.dataset import generate_splits, preprocess

# %%
# separate 200 samples for supervised training, all others are used in ssl training
num_supervised_train_data = 200 

# get split indices
sup_train_indices, val_indices, test_indices, ssl_train_indices = generate_splits(len(bank_df), 
                                                                            num_supervised_train_data,
                                                                            args['preproc']['validation_split'],
                                                                            args['preproc']['test_split'],
                                                                            args['seed'],)

# %%
df_proc, y_proc, no_num, no_cat, cats  = preprocess(bank_df, y, args['transformer']['cls_token_idx'])
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# This variables will need to be added to the config files in "configs/data/bank_*" before training

print('no of numerical columns: ', no_num)
print('no of categorical columns: ', no_cat)

print('list of categories in each categorical column: ', cats)
# Out:
# no of numerical columns:  7
# no of categorical columns:  10
# list of categories in each categorical column:  [1, 12, 3, 4, 2, 2, 2, 3, 12, 4]

# %%
#### args.num_features = args.no_num + args.no_cat

# split data into train, val and test using generated indices

train_df, train_y   = df_proc.iloc[sup_train_indices], y_proc.iloc[sup_train_indices]
val_df, val_y       = df_proc.iloc[val_indices], y_proc.iloc[val_indices]
test_df, test_y     = df_proc.iloc[test_indices], y_proc.iloc[test_indices]

# %%
# Generate data for self-supervised training if specified

train_ssl, train_ssl_y = None, None

if num_supervised_train_data != 'all':
    train_ssl, train_ssl_y = df_proc.iloc[ssl_train_indices], y_proc.iloc[ssl_train_indices]

# %%
# save dataframes in the data directory

train_df.to_csv('data/train.csv' , index=False)
train_y.to_csv('data/train_y.csv' , index=False)
val_df.to_csv('data/val.csv' , index=False)
val_y.to_csv('data/val_y.csv' , index=False)
test_df.to_csv('data/test.csv' , index=False)
test_y.to_csv('data/test_y.csv' , index=False)

if train_ssl is not None:
    train_ssl.to_csv('data/train_ssl.csv' , index=False)

if train_ssl_y is not None:
    train_ssl_y.to_csv('data/train_ssl_y.csv' , index=False)

# %% [markdown]
# ### Self-supervised training

# %%
# give the number of gpus available if any
num_gpus = 1

# %%
# Train saint model in self-supervised settings. 
# To use gpus, add trainer.gpus=1 where "1" is the total no of gpus to the command

# !python saint/main.py experiment=self-supervised \
    experiment.model=saint \
    data.data_folder=/content/saint/data \
    data=bank_ssl

# %%
# Retrieve the location of self-supervised pretrained model from logs

# for example
best_ssl_model_ckpt = "/content/outputs/2021-11-01/10-09-16/lightning_logs/version_0/checkpoints/0-916.ckpt"

# %%
# Train a supervised model initialized from the ssl model

# !python main.py experiment=supervised \
    experiment.model=saint \
    data.data_folder=/content/saint/data \
    data=bank_sup \
    experiment.pretrained_checkpoint={best_ssl_model_ckpt}
# Out:
# /opt/conda/lib/python3.10/site-packages/torch/cuda/__init__.py:619: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# /workspaces/saint/main.py:37: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_path="configs", config_name="config")
# no viable alternative at input '{best_ssl_model_ckpt}'
# See https://hydra.cc/docs/1.2/advanced/override_grammar/basic for details
#
# Set the environment variable HYDRA_FULL_ERROR=1 for a complete stack trace.

# %%
# You can also train a supervised model without initializing with a pretrained model i.e. randomly initialized

# !python main.py experiment=supervised \
    experiment.model=saint \
    data.data_folder=/workspaces/saint/data \
    data=bank_sup
# Out:
# /opt/conda/lib/python3.10/site-packages/torch/cuda/__init__.py:619: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# /workspaces/saint/main.py:37: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_path="configs", config_name="config")
# /opt/conda/lib/python3.10/site-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# Seed set to 1234
# SaintSupLightningModule(
#   (transformer): Encoder(
#     (layers): ModuleList(
#       (0-5): 6 x SaintLayer(
#         (msa): EncoderLayer(
#           (self_attn): MultiHeadedAttention(
#             (linears): ModuleList(
#               (0-3): 4 x Linear(in_features=32, out_features=32, bias=True)
#             )
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (feed_forward): PositionwiseFeedForward(
#             (w_1): Linear(in_features=32, out_features=32, bias=True)
#             (w_2): Linear(in_features=32, out_features=32, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#             (activation): GELU(approximate='none')
#           )
#           (sublayer): ModuleList(
#             (0-1): 2 x SublayerConnection(
#               (norm): LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#         (misa): EncoderLayer(
#           (self_attn): MultiHeadedIntersampleAttention(
#             (linears): ModuleList(
#               (0-3): 4 x Linear(in_features=32, out_features=32, bias=True)
#             )
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (feed_forward): PositionwiseFeedForward(
#             (w_1): Linear(in_features=32, out_features=32, bias=True)
#             (w_2): Linear(in_features=32, out_features=32, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#             (activation): GELU(approximate='none')
#           )
#           (sublayer): ModuleList(
#             (0-1): 2 x SublayerConnection(
#               (norm): LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#     )
#     (norm): LayerNorm()
#   )
#   (embedding): Embedding(
#     (cat_embedding): ModuleList(
#       (0): CategoricalEmbedding(
#         (embedding): Embedding(1, 32)
#       )
#       (1): CategoricalEmbedding(
#         (embedding): Embedding(12, 32)
#       )
#       (2): CategoricalEmbedding(
#         (embedding): Embedding(3, 32)
#       )
#       (3): CategoricalEmbedding(
#         (embedding): Embedding(4, 32)
#       )
#       (4-6): 3 x CategoricalEmbedding(
#         (embedding): Embedding(2, 32)
#       )
#       (7): CategoricalEmbedding(
#         (embedding): Embedding(3, 32)
#       )
#       (8): CategoricalEmbedding(
#         (embedding): Embedding(12, 32)
#       )
#       (9): CategoricalEmbedding(
#         (embedding): Embedding(4, 32)
#       )
#     )
#     (num_embedding): ModuleList(
#       (0-6): 7 x NumericalEmbedding(
#         (linear): Sequential(
#           (0): Linear(in_features=1, out_features=32, bias=True)
#           (1): ReLU()
#         )
#       )
#     )
#   )
#   (fc): Linear(in_features=32, out_features=1, bias=True)
#   (criterion): BCEWithLogitsLoss()
#   (train_metric): BinaryAUROC()
#   (valid_metric): BinaryAUROC()
#   (test_metric): BinaryAUROC()
# )
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# /opt/conda/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
#
#   | Name         | Type              | Params | Mode
# -----------------------------------------------------------
# 0 | transformer  | Encoder           | 65.0 K | train
# 1 | embedding    | Embedding         | 1.9 K  | train
# 2 | fc           | Linear            | 33     | train
# 3 | criterion    | BCEWithLogitsLoss | 0      | train
# 4 | train_metric | BinaryAUROC       | 0      | train
# 5 | valid_metric | BinaryAUROC       | 0      | train
# 6 | test_metric  | BinaryAUROC       | 0      | train
# -----------------------------------------------------------
# 66.9 K    Trainable params
# 0         Non-trainable params
# 66.9 K    Total params
# 0.268     Total estimated model params size (MB)
# 275       Modules in train mode
# 0         Modules in eval mode
# /opt/conda/lib/python3.10/site-packages/pytorch_lightning/loops/fit_loop.py:310: The number of training batches (7) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Epoch 0: 100%|████| 7/7 [00:00<00:00, 36.57it/s, v_num=0, train_loss_step=0.530]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/212 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/212 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                  | 1/212 [00:00<00:03, 54.36it/s]
# Validation DataLoader 0:   1%|▏                 | 2/212 [00:00<00:03, 69.77it/s]
# Validation DataLoader 0:   1%|▎                 | 3/212 [00:00<00:02, 81.22it/s]
# Validation DataLoader 0:   2%|▎                 | 4/212 [00:00<00:02, 88.21it/s]
# Validation DataLoader 0:   2%|▍                 | 5/212 [00:00<00:02, 93.68it/s]
# Validation DataLoader 0:   3%|▌                 | 6/212 [00:00<00:02, 97.65it/s]
# Validation DataLoader 0:   3%|▌                | 7/212 [00:00<00:02, 100.61it/s]
# Validation DataLoader 0:   4%|▋                | 8/212 [00:00<00:01, 103.07it/s]
# Validation DataLoader 0:   4%|▋                | 9/212 [00:00<00:01, 105.09it/s]
# Validation DataLoader 0:   5%|▊               | 10/212 [00:00<00:01, 106.72it/s]
# Validation DataLoader 0:   5%|▊               | 11/212 [00:00<00:01, 108.12it/s]
# Validation DataLoader 0:   6%|▉               | 12/212 [00:00<00:01, 109.09it/s]
# Validation DataLoader 0:   6%|▉               | 13/212 [00:00<00:01, 110.14it/s]
# Validation DataLoader 0:   7%|█               | 14/212 [00:00<00:01, 111.01it/s]
# Validation DataLoader 0:   7%|█▏              | 15/212 [00:00<00:01, 111.82it/s]
# Validation DataLoader 0:   8%|█▏              | 16/212 [00:00<00:01, 112.51it/s]
# Validation DataLoader 0:   8%|█▎              | 17/212 [00:00<00:01, 113.11it/s]
# Validation DataLoader 0:   8%|█▎              | 18/212 [00:00<00:01, 113.64it/s]
# Validation DataLoader 0:   9%|█▍              | 19/212 [00:00<00:01, 113.86it/s]
# Validation DataLoader 0:   9%|█▌              | 20/212 [00:00<00:01, 114.28it/s]
# Validation DataLoader 0:  10%|█▌              | 21/212 [00:00<00:01, 114.69it/s]
# Validation DataLoader 0:  10%|█▋              | 22/212 [00:00<00:01, 115.06it/s]
# Validation DataLoader 0:  11%|█▋              | 23/212 [00:00<00:01, 115.40it/s]
# Validation DataLoader 0:  11%|█▊              | 24/212 [00:00<00:01, 115.72it/s]
# Validation DataLoader 0:  12%|█▉              | 25/212 [00:00<00:01, 116.00it/s]
# Validation DataLoader 0:  12%|█▉              | 26/212 [00:00<00:01, 116.26it/s]
# Validation DataLoader 0:  13%|██              | 27/212 [00:00<00:01, 116.50it/s]
# Validation DataLoader 0:  13%|██              | 28/212 [00:00<00:01, 116.71it/s]
# Validation DataLoader 0:  14%|██▏             | 29/212 [00:00<00:01, 116.93it/s]
# Validation DataLoader 0:  14%|██▎             | 30/212 [00:00<00:01, 117.11it/s]
# Validation DataLoader 0:  15%|██▎             | 31/212 [00:00<00:01, 117.30it/s]
# Validation DataLoader 0:  15%|██▍             | 32/212 [00:00<00:01, 117.38it/s]
# Validation DataLoader 0:  16%|██▍             | 33/212 [00:00<00:01, 117.52it/s]
# Validation DataLoader 0:  16%|██▌             | 34/212 [00:00<00:01, 117.66it/s]
# Validation DataLoader 0:  17%|██▋             | 35/212 [00:00<00:01, 117.81it/s]
# Validation DataLoader 0:  98%|██████████████▋| 208/212 [00:01<00:00, 121.36it/s]
# Validation DataLoader 0:  99%|██████████████▊| 209/212 [00:01<00:00, 121.38it/s]
# Validation DataLoader 0:  99%|██████████████▊| 210/212 [00:01<00:00, 121.39it/s]
# Validation DataLoader 0: 100%|██████████████▉| 211/212 [00:01<00:00, 121.40it/s]
# Validation DataLoader 0: 100%|███████████████| 212/212 [00:01<00:00, 121.29it/s]
# Epoch 1: 100%|█| 7/7 [00:00<00:00, 27.56it/s, v_num=0, train_loss_step=0.459, va
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/212 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/212 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                  | 1/212 [00:00<00:03, 53.85it/s]
# Validation DataLoader 0:   1%|▏                 | 2/212 [00:00<00:03, 68.24it/s]
# Validation DataLoader 0:   1%|▎                 | 3/212 [00:00<00:02, 80.23it/s]
# Validation DataLoader 0:   2%|▎                 | 4/212 [00:00<00:02, 87.63it/s]
# Validation DataLoader 0:   2%|▍                 | 5/212 [00:00<00:02, 93.08it/s]
# Validation DataLoader 0:   3%|▌                 | 6/212 [00:00<00:02, 97.03it/s]
# Validation DataLoader 0:   3%|▌                | 7/212 [00:00<00:02, 100.17it/s]
# Validation DataLoader 0:   4%|▋                | 8/212 [00:00<00:01, 102.56it/s]
# Validation DataLoader 0:   4%|▋                | 9/212 [00:00<00:01, 104.57it/s]
# Validation DataLoader 0:   5%|▊               | 10/212 [00:00<00:01, 106.20it/s]
# Validation DataLoader 0:   5%|▊               | 11/212 [00:00<00:01, 107.60it/s]
# Validation DataLoader 0:   6%|▉               | 12/212 [00:00<00:01, 108.74it/s]
# Validation DataLoader 0:   6%|▉               | 13/212 [00:00<00:01, 109.80it/s]
# Validation DataLoader 0:   7%|█               | 14/212 [00:00<00:01, 110.54it/s]
# Validation DataLoader 0:   7%|█▏              | 15/212 [00:00<00:01, 111.38it/s]
# Validation DataLoader 0:   8%|█▏              | 16/212 [00:00<00:01, 112.05it/s]
# Validation DataLoader 0:   8%|█▎              | 17/212 [00:00<00:01, 112.66it/s]
# Validation DataLoader 0:   8%|█▎              | 18/212 [00:00<00:01, 113.20it/s]
# Validation DataLoader 0:   9%|█▍              | 19/212 [00:00<00:01, 113.69it/s]
# Validation DataLoader 0:   9%|█▌              | 20/212 [00:00<00:01, 114.11it/s]
# Validation DataLoader 0:  10%|█▌              | 21/212 [00:00<00:01, 114.56it/s]
# Validation DataLoader 0:  10%|█▋              | 22/212 [00:00<00:01, 114.94it/s]
# Validation DataLoader 0:  11%|█▋              | 23/212 [00:00<00:01, 115.32it/s]
# Validation DataLoader 0:  11%|█▊              | 24/212 [00:00<00:01, 115.39it/s]
# Validation DataLoader 0:  12%|█▉              | 25/212 [00:00<00:01, 115.69it/s]
# Validation DataLoader 0:  12%|█▉              | 26/212 [00:00<00:01, 115.97it/s]
# Validation DataLoader 0:  13%|██              | 27/212 [00:00<00:01, 116.21it/s]
# Validation DataLoader 0:  13%|██              | 28/212 [00:00<00:01, 116.45it/s]
# Validation DataLoader 0:  78%|███████████▋   | 165/212 [00:01<00:00, 120.22it/s]
# Validation DataLoader 0:  78%|███████████▋   | 166/212 [00:01<00:00, 120.23it/s]
# Validation DataLoader 0:  79%|███████████▊   | 167/212 [00:01<00:00, 120.23it/s]
# Validation DataLoader 0:  79%|███████████▉   | 168/212 [00:01<00:00, 120.24it/s]
# Validation DataLoader 0:  80%|███████████▉   | 169/212 [00:01<00:00, 120.25it/s]
# Validation DataLoader 0:  80%|████████████   | 170/212 [00:01<00:00, 120.26it/s]
# Validation DataLoader 0:  81%|████████████   | 171/212 [00:01<00:00, 120.26it/s]
# Validation DataLoader 0:  81%|████████████▏  | 172/212 [00:01<00:00, 120.27it/s]
# Validation DataLoader 0:  82%|████████████▏  | 173/212 [00:01<00:00, 120.27it/s]
# Validation DataLoader 0:  82%|████████████▎  | 174/212 [00:01<00:00, 120.28it/s]
# Validation DataLoader 0:  83%|████████████▍  | 175/212 [00:01<00:00, 120.29it/s]
# Validation DataLoader 0:  83%|████████████▍  | 176/212 [00:01<00:00, 120.30it/s]
# Validation DataLoader 0:  83%|████████████▌  | 177/212 [00:01<00:00, 120.30it/s]
# Validation DataLoader 0:  84%|████████████▌  | 178/212 [00:01<00:00, 120.31it/s]
# Validation DataLoader 0:  84%|████████████▋  | 179/212 [00:01<00:00, 120.32it/s]
# Validation DataLoader 0:  85%|████████████▋  | 180/212 [00:01<00:00, 120.33it/s]
# Validation DataLoader 0:  85%|████████████▊  | 181/212 [00:01<00:00, 120.34it/s]
# Validation DataLoader 0:  86%|████████████▉  | 182/212 [00:01<00:00, 120.35it/s]
# Validation DataLoader 0:  86%|████████████▉  | 183/212 [00:01<00:00, 120.36it/s]
# Validation DataLoader 0:  87%|█████████████  | 184/212 [00:01<00:00, 120.37it/s]
# Validation DataLoader 0:  87%|█████████████  | 185/212 [00:01<00:00, 120.37it/s]
# Validation DataLoader 0:  88%|█████████████▏ | 186/212 [00:01<00:00, 120.37it/s]
# Validation DataLoader 0:  88%|█████████████▏ | 187/212 [00:01<00:00, 120.38it/s]
# Validation DataLoader 0:  89%|█████████████▎ | 188/212 [00:01<00:00, 120.39it/s]
# Validation DataLoader 0:  89%|█████████████▎ | 189/212 [00:01<00:00, 120.39it/s]
# Validation DataLoader 0:  90%|█████████████▍ | 190/212 [00:01<00:00, 120.29it/s]
# Validation DataLoader 0:  90%|█████████████▌ | 191/212 [00:01<00:00, 120.19it/s]
# Validation DataLoader 0:  91%|█████████████▌ | 192/212 [00:01<00:00, 120.10it/s]
# Validation DataLoader 0:  91%|█████████████▋ | 193/212 [00:01<00:00, 120.00it/s]
# Validation DataLoader 0:  92%|█████████████▋ | 194/212 [00:01<00:00, 119.91it/s]
# Validation DataLoader 0:  92%|█████████████▊ | 195/212 [00:01<00:00, 119.81it/s]
# Validation DataLoader 0:  92%|█████████████▊ | 196/212 [00:01<00:00, 119.81it/s]
# Validation DataLoader 0:  93%|█████████████▉ | 197/212 [00:01<00:00, 119.83it/s]
# Validation DataLoader 0:  93%|██████████████ | 198/212 [00:01<00:00, 119.84it/s]
# Validation DataLoader 0:  94%|██████████████ | 199/212 [00:01<00:00, 119.86it/s]
# Validation DataLoader 0:  94%|██████████████▏| 200/212 [00:01<00:00, 119.87it/s]
# Validation DataLoader 0:  95%|██████████████▏| 201/212 [00:01<00:00, 119.89it/s]
# Validation DataLoader 0:  95%|██████████████▎| 202/212 [00:01<00:00, 119.91it/s]
# Validation DataLoader 0:  96%|██████████████▎| 203/212 [00:01<00:00, 119.92it/s]
# Validation DataLoader 0:  96%|██████████████▍| 204/212 [00:01<00:00, 119.94it/s]
# Validation DataLoader 0:  97%|██████████████▌| 205/212 [00:01<00:00, 119.96it/s]
# Validation DataLoader 0:  97%|██████████████▌| 206/212 [00:01<00:00, 119.97it/s]
# Validation DataLoader 0:  98%|██████████████▋| 207/212 [00:01<00:00, 119.99it/s]
# Validation DataLoader 0:  98%|██████████████▋| 208/212 [00:01<00:00, 120.00it/s]
# Validation DataLoader 0:  99%|██████████████▊| 209/212 [00:01<00:00, 120.02it/s]
# Validation DataLoader 0:  99%|██████████████▊| 210/212 [00:01<00:00, 120.03it/s]
# Validation DataLoader 0: 100%|██████████████▉| 211/212 [00:01<00:00, 120.05it/s]
# Validation DataLoader 0: 100%|███████████████| 212/212 [00:01<00:00, 119.96it/s]
# Epoch 2: 100%|█| 7/7 [00:00<00:00, 28.02it/s, v_num=0, train_loss_step=0.290, va
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/212 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/212 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                  | 1/212 [00:00<00:04, 51.27it/s]
# Validation DataLoader 0:   1%|▏                 | 2/212 [00:00<00:03, 65.14it/s]
# Validation DataLoader 0:   1%|▎                 | 3/212 [00:00<00:02, 76.72it/s]
# Validation DataLoader 0:   2%|▎                 | 4/212 [00:00<00:02, 84.62it/s]
# Validation DataLoader 0:   2%|▍                 | 5/212 [00:00<00:02, 90.24it/s]
# Validation DataLoader 0:   3%|▌                 | 6/212 [00:00<00:02, 94.34it/s]
# Validation DataLoader 0:   3%|▌                 | 7/212 [00:00<00:02, 97.53it/s]
# Validation DataLoader 0:   4%|▋                | 8/212 [00:00<00:02, 100.11it/s]
# Validation DataLoader 0:   4%|▋                | 9/212 [00:00<00:01, 102.23it/s]
# Validation DataLoader 0:   5%|▊               | 10/212 [00:00<00:01, 104.02it/s]
# Validation DataLoader 0:   5%|▊               | 11/212 [00:00<00:01, 105.52it/s]
# Validation DataLoader 0:   6%|▉               | 12/212 [00:00<00:01, 106.80it/s]
# Validation DataLoader 0:   6%|▉               | 13/212 [00:00<00:01, 107.91it/s]
# Validation DataLoader 0:   7%|█               | 14/212 [00:00<00:01, 108.57it/s]
# Validation DataLoader 0:   7%|█▏              | 15/212 [00:00<00:01, 109.40it/s]
# Validation DataLoader 0:   8%|█▏              | 16/212 [00:00<00:01, 110.11it/s]
# Validation DataLoader 0:   8%|█▎              | 17/212 [00:00<00:01, 110.73it/s]
# Validation DataLoader 0:   8%|█▎              | 18/212 [00:00<00:01, 111.35it/s]
# Validation DataLoader 0:   9%|█▍              | 19/212 [00:00<00:01, 111.93it/s]
# Validation DataLoader 0:   9%|█▌              | 20/212 [00:00<00:01, 112.46it/s]
# Validation DataLoader 0:  10%|█▌              | 21/212 [00:00<00:01, 112.93it/s]
# Validation DataLoader 0:  10%|█▋              | 22/212 [00:00<00:01, 113.36it/s]
# Validation DataLoader 0:  73%|██████████▉    | 154/212 [00:01<00:00, 101.01it/s]
# Validation DataLoader 0:  73%|██████████▉    | 155/212 [00:01<00:00, 101.05it/s]
# Validation DataLoader 0:  74%|███████████    | 156/212 [00:01<00:00, 101.09it/s]
# Validation DataLoader 0:  74%|███████████    | 157/212 [00:01<00:00, 101.13it/s]
# Validation DataLoader 0:  75%|███████████▏   | 158/212 [00:01<00:00, 101.10it/s]
# Validation DataLoader 0:  75%|███████████▎   | 159/212 [00:01<00:00, 101.07it/s]
# Validation DataLoader 0:  75%|███████████▎   | 160/212 [00:01<00:00, 101.04it/s]
# Validation DataLoader 0:  76%|███████████▍   | 161/212 [00:01<00:00, 101.02it/s]
# Validation DataLoader 0:  76%|███████████▍   | 162/212 [00:01<00:00, 100.99it/s]
# Validation DataLoader 0:  77%|███████████▌   | 163/212 [00:01<00:00, 100.96it/s]
# Validation DataLoader 0:  77%|███████████▌   | 164/212 [00:01<00:00, 100.93it/s]
# Validation DataLoader 0:  78%|███████████▋   | 165/212 [00:01<00:00, 100.89it/s]
# Validation DataLoader 0:  78%|███████████▋   | 166/212 [00:01<00:00, 100.84it/s]
# Validation DataLoader 0:  79%|███████████▊   | 167/212 [00:01<00:00, 100.81it/s]
# Validation DataLoader 0:  79%|███████████▉   | 168/212 [00:01<00:00, 100.78it/s]
# Validation DataLoader 0:  80%|███████████▉   | 169/212 [00:01<00:00, 100.76it/s]
# Validation DataLoader 0:  80%|████████████   | 170/212 [00:01<00:00, 100.73it/s]
# Validation DataLoader 0:  81%|████████████   | 171/212 [00:01<00:00, 100.71it/s]
# Validation DataLoader 0:  81%|████████████▏  | 172/212 [00:01<00:00, 100.68it/s]
# Validation DataLoader 0:  82%|████████████▏  | 173/212 [00:01<00:00, 100.69it/s]
# Validation DataLoader 0:  82%|████████████▎  | 174/212 [00:01<00:00, 100.71it/s]
# Validation DataLoader 0:  83%|████████████▍  | 175/212 [00:01<00:00, 100.73it/s]
# Validation DataLoader 0:  83%|████████████▍  | 176/212 [00:01<00:00, 100.75it/s]
# Validation DataLoader 0:  83%|████████████▌  | 177/212 [00:01<00:00, 100.77it/s]
# Validation DataLoader 0:  84%|████████████▌  | 178/212 [00:01<00:00, 100.86it/s]
# Validation DataLoader 0:  84%|████████████▋  | 179/212 [00:01<00:00, 100.97it/s]
# Validation DataLoader 0:  85%|████████████▋  | 180/212 [00:01<00:00, 101.07it/s]
# Validation DataLoader 0:  85%|████████████▊  | 181/212 [00:01<00:00, 101.17it/s]
# Validation DataLoader 0:  86%|████████████▉  | 182/212 [00:01<00:00, 101.27it/s]
# Validation DataLoader 0:  86%|████████████▉  | 183/212 [00:01<00:00, 101.28it/s]
# Validation DataLoader 0:  87%|█████████████  | 184/212 [00:01<00:00, 101.25it/s]
# Validation DataLoader 0:  87%|█████████████  | 185/212 [00:01<00:00, 101.23it/s]
# Validation DataLoader 0:  88%|█████████████▏ | 186/212 [00:01<00:00, 101.20it/s]
# Validation DataLoader 0:  88%|█████████████▏ | 187/212 [00:01<00:00, 101.17it/s]
# Validation DataLoader 0:  89%|█████████████▎ | 188/212 [00:01<00:00, 101.16it/s]
# Validation DataLoader 0:  89%|█████████████▎ | 189/212 [00:01<00:00, 101.13it/s]
# Validation DataLoader 0:  90%|█████████████▍ | 190/212 [00:01<00:00, 101.18it/s]
# Validation DataLoader 0:  90%|█████████████▌ | 191/212 [00:01<00:00, 101.27it/s]
# Validation DataLoader 0:  91%|█████████████▌ | 192/212 [00:01<00:00, 101.37it/s]
# Validation DataLoader 0:  91%|█████████████▋ | 193/212 [00:01<00:00, 101.38it/s]
# Validation DataLoader 0:  92%|█████████████▋ | 194/212 [00:01<00:00, 101.35it/s]
# Validation DataLoader 0:  92%|█████████████▊ | 195/212 [00:01<00:00, 101.33it/s]
# Validation DataLoader 0:  92%|█████████████▊ | 196/212 [00:01<00:00, 101.31it/s]
# Validation DataLoader 0:  93%|█████████████▉ | 197/212 [00:01<00:00, 101.28it/s]
# Validation DataLoader 0:  93%|██████████████ | 198/212 [00:01<00:00, 101.26it/s]
# Validation DataLoader 0:  94%|██████████████ | 199/212 [00:01<00:00, 101.24it/s]
# Validation DataLoader 0:  94%|██████████████▏| 200/212 [00:01<00:00, 101.22it/s]
# Validation DataLoader 0:  95%|██████████████▏| 201/212 [00:01<00:00, 101.17it/s]
# Validation DataLoader 0:  95%|██████████████▎| 202/212 [00:01<00:00, 101.11it/s]
# Validation DataLoader 0:  96%|██████████████▎| 203/212 [00:02<00:00, 101.07it/s]
# Validation DataLoader 0:  96%|██████████████▍| 204/212 [00:02<00:00, 101.03it/s]
# Validation DataLoader 0:  97%|██████████████▌| 205/212 [00:02<00:00, 101.00it/s]
# Validation DataLoader 0:  97%|██████████████▌| 206/212 [00:02<00:00, 100.99it/s]
# Validation DataLoader 0:  98%|██████████████▋| 207/212 [00:02<00:00, 100.96it/s]
# Validation DataLoader 0:  98%|██████████████▋| 208/212 [00:02<00:00, 100.92it/s]
# Validation DataLoader 0:  99%|██████████████▊| 209/212 [00:02<00:00, 100.91it/s]
# Validation DataLoader 0:  99%|██████████████▊| 210/212 [00:02<00:00, 100.91it/s]
# Validation DataLoader 0: 100%|██████████████▉| 211/212 [00:02<00:00, 100.92it/s]
# Validation DataLoader 0: 100%|███████████████| 212/212 [00:02<00:00, 100.84it/s]
# Epoch 72: 100%|█| 7/7 [00:00<00:00, 24.24it/s, v_num=0, train_loss_step=0.199, v
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/212 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/212 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                  | 1/212 [00:00<00:04, 50.52it/s]
# Validation DataLoader 0:   1%|▏                 | 2/212 [00:00<00:03, 63.48it/s]
# Validation DataLoader 0:   1%|▎                 | 3/212 [00:00<00:02, 74.55it/s]
# Validation DataLoader 0:   2%|▎                 | 4/212 [00:00<00:02, 81.36it/s]
# Validation DataLoader 0:   2%|▍                 | 5/212 [00:00<00:02, 85.90it/s]
# Validation DataLoader 0:   3%|▌                 | 6/212 [00:00<00:02, 89.34it/s]
# Validation DataLoader 0:   3%|▌                 | 7/212 [00:00<00:02, 92.01it/s]
# Validation DataLoader 0:   4%|▋                 | 8/212 [00:00<00:02, 94.11it/s]
# Validation DataLoader 0:   4%|▊                 | 9/212 [00:00<00:02, 95.81it/s]
# Validation DataLoader 0:   5%|▊                | 10/212 [00:00<00:02, 97.19it/s]
# Validation DataLoader 0:   5%|▉                | 11/212 [00:00<00:02, 98.37it/s]
# Validation DataLoader 0:   6%|▉                | 12/212 [00:00<00:02, 99.40it/s]
# Validation DataLoader 0:   6%|▉               | 13/212 [00:00<00:01, 100.27it/s]
# Validation DataLoader 0:   7%|█               | 14/212 [00:00<00:01, 100.97it/s]
# Validation DataLoader 0:   7%|█▏              | 15/212 [00:00<00:01, 101.60it/s]
# Validation DataLoader 0:   8%|█▏              | 16/212 [00:00<00:01, 102.22it/s]
# Validation DataLoader 0:   8%|█▎              | 17/212 [00:00<00:01, 102.71it/s]
# Validation DataLoader 0:   8%|█▎              | 18/212 [00:00<00:01, 103.19it/s]
# Validation DataLoader 0:   9%|█▍              | 19/212 [00:00<00:01, 103.61it/s]
# Validation DataLoader 0:   9%|█▌              | 20/212 [00:00<00:01, 103.98it/s]
# Validation DataLoader 0:  10%|█▌              | 21/212 [00:00<00:01, 104.28it/s]
# Validation DataLoader 0:  10%|█▋              | 22/212 [00:00<00:01, 104.61it/s]
# Validation DataLoader 0:  11%|█▋              | 23/212 [00:00<00:01, 104.91it/s]
# Validation DataLoader 0:  11%|█▊              | 24/212 [00:00<00:01, 105.19it/s]
# Validation DataLoader 0:  12%|█▉              | 25/212 [00:00<00:01, 105.42it/s]
# Validation DataLoader 0:  12%|█▉              | 26/212 [00:00<00:01, 105.66it/s]
# Validation DataLoader 0:  13%|██              | 27/212 [00:00<00:01, 105.85it/s]
# Validation DataLoader 0:  13%|██              | 28/212 [00:00<00:01, 106.07it/s]
# Validation DataLoader 0:  14%|██▏             | 29/212 [00:00<00:01, 106.25it/s]
# Validation DataLoader 0:  14%|██▎             | 30/212 [00:00<00:01, 106.43it/s]
# Validation DataLoader 0:  15%|██▎             | 31/212 [00:00<00:01, 106.58it/s]
# Validation DataLoader 0:  17%|██▋             | 36/212 [00:00<00:01, 107.23it/s]
# Validation DataLoader 0:  17%|██▊             | 37/212 [00:00<00:01, 107.31it/s]
# Validation DataLoader 0:  18%|██▊             | 38/212 [00:00<00:01, 107.31it/s]
# Validation DataLoader 0:  18%|██▉             | 39/212 [00:00<00:01, 107.38it/s]
# Validation DataLoader 0:  19%|███             | 40/212 [00:00<00:01, 107.47it/s]^C
#
# Detected KeyboardInterrupt, attempting graceful shutdown ...
# Epoch 72: 100%|█| 7/7 [00:00<00:00,  8.52it/s, v_num=0, train_loss_step=0.199, v

# %%
# To predict on a test dataset  # check saint/experiment/predict for params

pretrained_checkpoint = "/content/outputs/2021-11-01/13-30-49/lightning_logs/version_0/checkpoints/2-20.ckpt"

# !python saint/predict.py experiment=predict \
    experiment.model=saint \
    data=bank_sup \
    data.data_folder=/content/saint/data \
    experiment.pretrained_checkpoint={pretrained_checkpoint} \
    experiment.pred_sav_path=/content/predict.csv

# %% [markdown]
# ## View Tensorboard

# %%
# View plots and hyperparameters

# %load_ext tensorboard
# %tensorboard --logdir /content/outputs/2021-11-01/10-14-14/lightning_logs # change lightning log path

# %% [markdown]
# ## The End
